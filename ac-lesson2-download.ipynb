# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
from fastai import *
from fastai.vision import *

# %%
plt.style.use(['dark_background'])

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
PATH = Path('data/classifier/purses')

# %%
for p in PATH.glob("*.txt"):
    dest = p.parent/str(p.stem).split('_')[1]
    dest.mkdir(parents=True, exist_ok=True)
    download_images(p, dest)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='485' class='' max='485', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [485/485 00:48<00:00]
#     </div>
# Error https://item3.tradesy.com/images/celine-luggage-new-micro-with-interstice-dark-taupe-leather-tote-14417347-0-1.jpg?width=720&height=960 'content-length'
# Error http://www.happypursuits.com/wp-content/uploads/2017/08/1.-Celine-Luggage-Nano-Micro-Mini-Phantom.png 'content-length'
# Error https://www.fashionphile.com/includes/images/thumb/BW298269/celine-drummed-calfskin-nano-luggage-black-00.jpg 'content-length'
# Error http://www.aaareplicabagshop.com/photo/mk/replica-celine-luggage-nano-2635-20070.jpg 'content-length'
# Error http://www.aaareplicabagshop.com/photo/mk/replica-celine-phantom-bags-2728-20894.jpg 'content-length'
# Error https://www.fashionphile.com/includes/images/thumb/BD297552/celine-drummed-calfskin-nano-luggage-vermillion-00.jpg 'content-length'
# Error http://www.fashionphile.com//includes/images/BW67490/BW67490-CELINE%20DRUMMED%20LEATHER%20MICRO%20LUGGAGE%20COQUELICOT_A.jpg 'content-length'
# Error https://item3.tradesy.com/images/celine-luggage-nano-cobalt-blue-leather-cross-body-bag-23321247-0-1.jpg?width=720&height=960 'content-length'
# Error http://www.bagswalletsit.com/media/catalog/product/cache/1/image/1125x/9df78eab33525d08d6e5fb8d27136e95/c/m/cm26grk.jpg 'content-length'
# Error https://cdnd.lystit.com/1200/630/tr/photos/2012/01/12/celine-lipstick-calfskin-micro-luggage-shopper-tote-product-1-2707725-873175550.jpeg 'content-length'
# Error http://www.happypursuits.com/wp-content/uploads/2016
>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error http://deluxemall.com/attachments/celine/415002d1367474022-sold-celine-burgundy-beige-gray-small-trapeze-w-shoulder-strap-2013-05-01-15.53.23-1.jpg 'content-length'
# Error http://www.mma-angouleme.fr/nikerequin/pic/sac%20celine%20it%20bag,sac%20style%20celine%20trapeze,petit%20sac%20celine%20bandouliere.jpg 'content-length'
# Error http://deluxemall.com/attachments/celine/616882d1410846422-celine-trapeze-long-strap-handbag-terracotta-selling-swap-celine-trapeze.jpg 'content-length'
# Error http://glamradar.com/wp-content/uploads/2014/08/all-black-trapeze-bag.jpg 'content-length'
# Error http://deluxemall.com/attachments/celine/444155d1373481657-good-price-brand-new-python-trapeze-celinebluepython.jpg 'content-length'
# Error http://deluxemall.com/attachments/celine/590236d1404870525-closed-celine-trapeze-medium-croc-black-celine-trapeze-medium-croco.jpg 'content-length'
# Error http://www.wewonwon.com/images/Celine-Grey-Felt-Trapeze-Bag-Fall-2013.jpg HTTPConnectionPool(host='www.wewonwon.com', port=80): Max retries exceeded with url: /images/Celine-Grey-Felt-Trapeze-Bag-Fall-2013.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa4cc882cc0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
# Error http://deluxemall.com/attachments/celine/485237d1382412660-sold-brand-new-celine-trapeze-strap-grained-coq-2013-10-22-11.30.24.jpg 'content-length'
# Error http://deluxemall.com/attachments/celine/615203d1410356468-brand-new-celine-trapeze-bag-red-python-skin-image.jpg 'content-length'
# Error http://deluxemall.com/attachments/celine/429940d1370662213-sold-celine-trapeze-tricolor-burgundy-grey-cream-leather-tote-bag-1950-nego-celine-8.jpg 'content-length'
# Error http://deluxemall.com/attachments/celine/522277d1389028431-black-leather-suede-celine-trapeze-strap-20140104_150130.jpg 'content-length'
# Error http://www.thankstofashion.com/t2f/wp-content/uploads/2014/10/Celine-Trapeze-black.jpg 'content-length'
# Error http://www.justatinabit.com/wp-content/uploads/2016/03/justatinabit-Celine-Trapeze-Tricolor-Leather-Medium-celine-tote-bag-street-style-outfit-6.jpg 'content-length'
# Error http://deluxemall.com/attachments/celine/393388d1363033578-nwt-100-auth-celine-trapeze-whipsnake-bag-winter-2012-rare-img_3847.jpg 'content-length'
# Error http://deluxemall.com/attachments/celine/321893d1346487246-sold-brand-new-celine-trapeze-tricolor-long-strap-blue-wing-celine-mania.jpg 'content-length'
# Error http://www.designerhandbagshows.com/img/Celine-Trapeze-Bag.jpg ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Error http://www.lust4labels.com/wp-content/uploads/2018/09/celine-trapeze.jpg HTTPConnectionPool(host='www.lust4labels.com', port=80): Max retries exceeded with url: /wp-content/uploads/2018/09/celine-trapeze.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa4cc850fd0>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# Error http://www.fashionenewshow.com/img/Celine-Trapeze-Trio-Bag-beige.jpg HTTPConnectionPool(host='www.fashionenewshow.com', port=80): Max retries exceeded with url: /img/Celine-Trapeze-Trio-Bag-beige.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa4cc79bf28>: Failed to establish a new connection: [Errno 110] Connection timed out',))

# %% [markdown]
# You will need to run this line once per each category.

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images than can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for p in PATH.glob("*.txt"):
    dest = p.parent/str(p.stem).split('_')[1]
    print(dest)
    verify_images(dest, delete=True, max_workers=8)
# Out:
# data/classifier/purses/celine-luggage
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='423' class='' max='423', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [423/423 00:10<00:00]
#     </div>
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000436.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000314.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000377.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000124.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000232.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000278.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000358.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000364.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000070.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000024.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000408.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000247.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-luggage/00000127.jpg'
# data/classifier/purses/channel-flap
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='491' class='' max='491', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [491/491 00:13<00:00]
#     </div>
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000379.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000308.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000496.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000055.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000132.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000430.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000389.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000209.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000504.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000137.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000514.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000249.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000204.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000415.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000284.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000520.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000163.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000115.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000487.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000513.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000394.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000402.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/channel-flap/00000536.jpg'
# data/classifier/purses/hermes-kelly
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='428' class='' max='428', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [428/428 00:11<00:00]
#     </div>
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000186.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000244.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000044.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000105.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000122.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000048.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000328.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000174.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000243.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000189.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000249.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000290.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000176.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000112.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000310.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000223.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000156.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000425.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000070.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000082.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000420.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/hermes-kelly/00000255.jpg'
# data/classifier/purses/celine-trapeze
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='375' class='' max='375', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [375/375 00:11<00:00]
#     </div>
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000191.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000251.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000226.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000386.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000193.jpg'
# /opt/anaconda3/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /opt/anaconda3/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000388.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000446.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000239.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000045.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000218.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000284.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000224.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000051.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000408.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000238.jpg'
# cannot identify image file '/home/jupyter/.fastai/data/classifier/purses/celine-trapeze/00000255.jpg'

# %% [markdown]
# ## View data

# %%
np.random.seed(66)
data = ImageDataBunch.from_folder(PATH, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['celine-luggage', 'celine-trapeze', 'channel-flap', 'hermes-kelly']

# %%
data.show_batch(rows=3, figsize=(12,12))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['celine-luggage', 'celine-trapeze', 'channel-flap', 'hermes-kelly'],
#  4,
#  1236,
#  312)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 01:44
# epoch  train_loss  valid_loss  error_rate
# 1      0.983461    0.305914    0.099359    (00:26)
# 2      0.622106    0.292223    0.105769    (00:26)
# 3      0.466494    0.258353    0.076923    (00:24)
# 4      0.383723    0.263698    0.083333    (00:26)

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.lr_find(7e-5, 5e-4)
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.load('stage-1')

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-4,2e-4))
# Out:
# Total time: 01:43
# epoch  train_loss  valid_loss  error_rate
# 1      0.231728    0.264687    0.070513    (00:24)
# 2      0.178630    0.218760    0.067308    (00:26)
# 3      0.132875    0.178693    0.041667    (00:25)
# 4      0.098146    0.162574    0.038462    (00:27)

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.most_confused(min_val=1)
# Out:
# [('celine-trapeze', 'celine-luggage', 2),
#  ('channel-flap', 'celine-trapeze', 2),
#  ('hermes-kelly', 'celine-luggage', 2),
#  ('hermes-kelly', 'celine-trapeze', 2)]

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `FileDeleter` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.
#
# First we need to get the file paths from our top_losses. Here's a handy function that pulls out all our top_losses:

# %%
from fastai.widgets import *

losses,idxs = interp.top_losses()
top_loss_paths = data.valid_ds.x[idxs]

# %% [markdown]
# Now we can pass in these paths to our widget.

# %%
fd = FileDeleter(file_paths=top_loss_paths)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff…
# Button(button_style='primary', description='Confirm', style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Confirm' to delete flagged photos and keep the rest in that row. The `File_Deleter` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses`.

# %% [markdown]
# ## Putting your model in production

# %%
data.classes
# Out:
# ['celine-luggage', 'celine-trapeze', 'channel-flap', 'hermes-kelly']

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
# fastai.defaults.device = torch.device('cpu')

# %%
img = open_image(PATH/'celine-trapeze'/'00000077.jpg')
img
# Out:
# Image (3, 460, 748)

# %%
data2 = ImageDataBunch.single_from_classes(PATH, data.classes, tfms=get_transforms(), size=224).normalize(imagenet_stats)
learn = create_cnn(data2, models.resnet34)
learn.load('stage-2')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# 'celine-trapeze'

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:13
# epoch  train_loss  valid_loss  error_rate
# 1      12.220007   1144188288.000000  0.765957    (00:13)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 01:07
# epoch  train_loss  valid_loss  error_rate
# 1      1.349151    1.062807    0.609929    (00:13)
# 2      1.373262    1.045115    0.546099    (00:13)
# 3      1.346169    1.006288    0.468085    (00:13)
# 4      1.334486    0.978713    0.453901    (00:13)
# 5      1.320978    0.978108    0.446809    (00:13)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.602823    0.119616    0.049645    (00:14)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 06:39
# epoch  train_loss  valid_loss  error_rate
# 1      1.513021    1.041628    0.507326    (00:13)
# 2      1.290093    0.994758    0.443223    (00:09)
# 3      1.185764    0.936145    0.410256    (00:09)
# 4      1.117229    0.838402    0.322344    (00:09)
# 5      1.022635    0.734872    0.252747    (00:09)
# 6      0.951374    0.627288    0.192308    (00:10)
# 7      0.916111    0.558621    0.184982    (00:09)
# 8      0.839068    0.503755    0.177656    (00:09)
# 9      0.749610    0.433475    0.144689    (00:09)
# 10     0.678583    0.367560    0.124542    (00:09)
# 11     0.615280    0.327029    0.100733    (00:10)
# 12     0.558776    0.298989    0.095238    (00:09)
# 13     0.518109    0.266998    0.084249    (00:09)
# 14     0.476290    0.257858    0.084249    (00:09)
# 15     0.436865    0.227299    0.067766    (00:09)
# 16     0.457189    0.236593    0.078755    (00:10)
# 17     0.420905    0.240185    0.080586    (00:10)
# 18     0.395686    0.255465    0.082418    (00:09)
# 19     0.373232    0.263469    0.080586    (00:09)
# 20     0.348988    0.258300    0.080586    (00:10)
# 21     0.324616    0.261346    0.080586    (00:09)
# 22     0.311310    0.236431    0.071429    (00:09)
# 23     0.328342    0.245841    0.069597    (00:10)
# 24     0.306411    0.235111    0.064103    (00:10)
# 25     0.289134    0.227465    0.069597    (00:09)
# 26     0.284814    0.226022    0.064103    (00:09)
# 27     0.268398    0.222791    0.067766    (00:09)
# 28     0.255431    0.227751    0.073260    (00:10)
# 29     0.240742    0.235949    0.071429    (00:09)
# 30     0.227140    0.225221    0.075092    (00:09)
# 31     0.213877    0.214789    0.069597    (00:09)
# 32     0.201631    0.209382    0.062271    (00:10)
# 33     0.189988    0.210684    0.065934    (00:09)
# 34     0.181293    0.214666    0.073260    (00:09)
# 35     0.184095    0.222575    0.073260    (00:09)
# 36     0.194615    0.229198    0.076923    (00:10)
# 37     0.186165    0.218206    0.075092    (00:09)
# 38     0.176623    0.207198    0.062271    (00:10)
# 39     0.166854    0.207256    0.065934    (00:10)
# 40     0.162692    0.206044    0.062271    (00:09)
